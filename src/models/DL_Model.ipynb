# %% [markdown]
# # Deep Learning On Poker Hand Dataset
# In this notebook, we will apply deep learning to enhance the prediction accuracy that we couldnt get from ML models.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Helper functions

# %%
import pandas as pd

def load_data(path):
    df = pd.read_csv(path)
    return df

# %%
from sklearn.preprocessing import StandardScaler

def scale_data(x):
    scaler = StandardScaler()
    x = scaler.fit_transform(x)
    return x

# %%
from sklearn.model_selection import train_test_split

def get_prep_data():
    df_train = load_data('../../dataset/poker-hand-traintest')
    df_test = load_data('../../dataset/poker-hand-test')
    
    df_train = df_train.iloc[:, 1:]
    df_test = df_test.iloc[:25009, 1:]
    
    df = pd.concat([df_train, df_test])
    
    x = df.iloc[:, 0:10]
    x = scale_data(x)
    y = df['Hand']
    data_splits = train_test_split(x, y, test_size=0.2)
    return data_splits

# %%
x_train, x_test, y_train, y_test = get_prep_data()
print(f'x_train: {x_train.shape} \ny_train: {y_train.shape} \nx_test: {x_test.shape} \ny_test: {y_test.shape}')
# Out:
# x_train: (40014, 10)
# y_train: (40014,)
# x_test: (10004, 10)
# y_test: (10004,)

# %% [markdown]
# ## Building DFFNN V1

# %%
from keras.models import Sequential
from keras.layers import Dense

model_v1 = Sequential()

#Layers (includes input, hidden, and output layers).
model_v1.add(Dense(units=128, input_dim=10, activation='relu'))
model_v1.add(Dense(units=128, activation='tanh'))
model_v1.add(Dense(units=128, activation='tanh'))
model_v1.add(Dense(units=128, activation='tanh'))
model_v1.add(Dense(units=128, activation='tanh'))
model_v1.add(Dense(units=128, activation='tanh'))
model_v1.add(Dense(units=128, activation='tanh'))
model_v1.add(Dense(units=10, activation='softmax'))
             
#Compiling the model.
model_v1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Summary of the model.
model_v1.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_68 (Dense)             (None, 128)               1408
# _________________________________________________________________
# dense_69 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_70 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_71 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_72 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_73 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_74 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_75 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_v1.fit(x_train, y_train, batch_size=500, epochs=150, validation_data=(x_test, y_test))
# Out:
# Epoch 1/150
# 81/81 [==============================] - 0s 5ms/step - loss: 1.0171 - accuracy: 0.5040 - val_loss: 0.9572 - val_accuracy: 0.5433
# Epoch 2/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9572 - accuracy: 0.5375 - val_loss: 0.9620 - val_accuracy: 0.5488
# Epoch 3/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9565 - accuracy: 0.5401 - val_loss: 0.9448 - val_accuracy: 0.5546
# Epoch 4/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9439 - accuracy: 0.5494 - val_loss: 0.9773 - val_accuracy: 0.4532
# Epoch 5/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9502 - accuracy: 0.5408 - val_loss: 0.9414 - val_accuracy: 0.5441
# Epoch 6/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9376 - accuracy: 0.5510 - val_loss: 0.9371 - val_accuracy: 0.5537
# Epoch 7/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9334 - accuracy: 0.5526 - val_loss: 0.9432 - val_accuracy: 0.5372
# Epoch 8/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9336 - accuracy: 0.5539 - val_loss: 0.9250 - val_accuracy: 0.5542
# Epoch 9/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9224 - accuracy: 0.5599 - val_loss: 0.9276 - val_accuracy: 0.5498
# Epoch 10/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9152 - accuracy: 0.5650 - val_loss: 0.9296 - val_accuracy: 0.5536
# Epoch 11/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9121 - accuracy: 0.5700 - val_loss: 0.9120 - val_accuracy: 0.5662
# Epoch 12/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9063 - accuracy: 0.5680 - val_loss: 0.9250 - val_accuracy: 0.5527
# Epoch 13/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9147 - accuracy: 0.5616 - val_loss: 0.9112 - val_accuracy: 0.5664
# Epoch 14/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9116 - accuracy: 0.5673 - val_loss: 0.9071 - val_accuracy: 0.5686
# Epoch 15/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8998 - accuracy: 0.5711 - val_loss: 0.8970 - val_accuracy: 0.5749
# Epoch 16/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8847 - accuracy: 0.5806 - val_loss: 0.9447 - val_accuracy: 0.5472
# Epoch 17/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.8930 - accuracy: 0.5765 - val_loss: 0.8857 - val_accuracy: 0.5759
# Epoch 18/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8800 - accuracy: 0.5827 - val_loss: 0.8963 - val_accuracy: 0.5697
# Epoch 19/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8720 - accuracy: 0.5900 - val_loss: 0.8734 - val_accuracy: 0.5904
# Epoch 20/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8626 - accuracy: 0.5952 - val_loss: 0.8790 - val_accuracy: 0.5960
# Epoch 21/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8576 - accuracy: 0.6012 - val_loss: 0.8962 - val_accuracy: 0.5840
# Epoch 22/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8587 - accuracy: 0.5987 - val_loss: 0.8889 - val_accuracy: 0.5872
# Epoch 23/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8483 - accuracy: 0.6076 - val_loss: 0.9244 - val_accuracy: 0.5772
# Epoch 24/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8296 - accuracy: 0.6221 - val_loss: 0.8418 - val_accuracy: 0.6095
# Epoch 25/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8147 - accuracy: 0.6267 - val_loss: 0.8819 - val_accuracy: 0.5883
# Epoch 26/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8087 - accuracy: 0.6283 - val_loss: 0.9157 - val_accuracy: 0.5822
# Epoch 27/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.8335 - accuracy: 0.6162 - val_loss: 0.8825 - val_accuracy: 0.6040
# Epoch 28/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.7860 - accuracy: 0.6428 - val_loss: 0.9894 - val_accuracy: 0.5510
# Epoch 29/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7743 - accuracy: 0.6476 - val_loss: 0.7798 - val_accuracy: 0.6426
# Epoch 30/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7451 - accuracy: 0.6616 - val_loss: 0.7620 - val_accuracy: 0.6573
# Epoch 31/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7292 - accuracy: 0.6733 - val_loss: 0.8328 - val_accuracy: 0.6321
# Epoch 32/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7952 - accuracy: 0.6417 - val_loss: 0.7933 - val_accuracy: 0.6414
# Epoch 33/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7251 - accuracy: 0.6718 - val_loss: 0.7545 - val_accuracy: 0.6559
# Epoch 34/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7179 - accuracy: 0.6779 - val_loss: 0.8278 - val_accuracy: 0.6294
# Epoch 35/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7182 - accuracy: 0.6792 - val_loss: 0.9763 - val_accuracy: 0.5684
# Epoch 36/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7194 - accuracy: 0.6787 - val_loss: 0.7117 - val_accuracy: 0.6819
# Epoch 37/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6751 - accuracy: 0.6973 - val_loss: 0.7336 - val_accuracy: 0.6713
# Epoch 38/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6635 - accuracy: 0.7032 - val_loss: 0.7139 - val_accuracy: 0.6759
# Epoch 39/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6633 - accuracy: 0.7030 - val_loss: 0.8130 - val_accuracy: 0.6249
# Epoch 40/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6910 - accuracy: 0.6887 - val_loss: 0.7731 - val_accuracy: 0.6458
# Epoch 41/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6626 - accuracy: 0.7038 - val_loss: 0.7479 - val_accuracy: 0.6621
# Epoch 42/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6481 - accuracy: 0.7104 - val_loss: 0.7647 - val_accuracy: 0.6592
# Epoch 43/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6480 - accuracy: 0.7075 - val_loss: 0.7516 - val_accuracy: 0.6655
# Epoch 44/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.7164 - val_loss: 0.6508 - val_accuracy: 0.7087
# Epoch 45/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6292 - accuracy: 0.7190 - val_loss: 0.8980 - val_accuracy: 0.5853
# Epoch 46/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6299 - accuracy: 0.7175 - val_loss: 0.6660 - val_accuracy: 0.7018
# Epoch 47/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6007 - accuracy: 0.7316 - val_loss: 0.6690 - val_accuracy: 0.7015
# Epoch 48/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5897 - accuracy: 0.7386 - val_loss: 0.7753 - val_accuracy: 0.6741
# Epoch 49/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6563 - accuracy: 0.7083 - val_loss: 0.7255 - val_accuracy: 0.6857
# Epoch 50/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5659 - accuracy: 0.7514 - val_loss: 0.6450 - val_accuracy: 0.7169
# Epoch 51/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.7490 - val_loss: 0.7263 - val_accuracy: 0.6873
# Epoch 52/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5677 - accuracy: 0.7491 - val_loss: 0.7087 - val_accuracy: 0.6924
# Epoch 53/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5497 - accuracy: 0.7560 - val_loss: 0.6121 - val_accuracy: 0.7346
# Epoch 54/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5153 - accuracy: 0.7744 - val_loss: 0.6137 - val_accuracy: 0.7324
# Epoch 55/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5084 - accuracy: 0.7797 - val_loss: 0.7408 - val_accuracy: 0.7036
# Epoch 56/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5133 - accuracy: 0.7780 - val_loss: 0.5702 - val_accuracy: 0.7531
# Epoch 57/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4929 - accuracy: 0.7878 - val_loss: 0.7216 - val_accuracy: 0.6950
# Epoch 58/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5226 - accuracy: 0.7729 - val_loss: 0.7873 - val_accuracy: 0.6643
# Epoch 59/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5110 - accuracy: 0.7795 - val_loss: 0.8240 - val_accuracy: 0.6475
# Epoch 60/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4878 - accuracy: 0.7892 - val_loss: 0.5399 - val_accuracy: 0.7673
# Epoch 61/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.4683 - accuracy: 0.7978 - val_loss: 0.6189 - val_accuracy: 0.7442
# Epoch 62/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4462 - accuracy: 0.8099 - val_loss: 0.5285 - val_accuracy: 0.7726
# Epoch 63/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4007 - accuracy: 0.8304 - val_loss: 1.0434 - val_accuracy: 0.5945
# Epoch 64/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4820 - accuracy: 0.7971 - val_loss: 0.5123 - val_accuracy: 0.7817
# Epoch 65/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3876 - accuracy: 0.8380 - val_loss: 0.6131 - val_accuracy: 0.7394
# Epoch 66/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4326 - accuracy: 0.8186 - val_loss: 0.6001 - val_accuracy: 0.7511
# Epoch 67/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3704 - accuracy: 0.8454 - val_loss: 0.4001 - val_accuracy: 0.8269
# Epoch 68/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3166 - accuracy: 0.8665 - val_loss: 0.4488 - val_accuracy: 0.8192
# Epoch 69/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3431 - accuracy: 0.8566 - val_loss: 0.4227 - val_accuracy: 0.8281
# Epoch 70/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3060 - accuracy: 0.8737 - val_loss: 0.8754 - val_accuracy: 0.7249
# Epoch 71/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4172 - accuracy: 0.8353 - val_loss: 0.4100 - val_accuracy: 0.8263
# Epoch 72/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2896 - accuracy: 0.8798 - val_loss: 0.4665 - val_accuracy: 0.8064
# Epoch 73/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2823 - accuracy: 0.8845 - val_loss: 0.3725 - val_accuracy: 0.8495
# Epoch 74/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2059 - accuracy: 0.9191 - val_loss: 0.2869 - val_accuracy: 0.8822
# Epoch 75/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.2397 - accuracy: 0.9039 - val_loss: 0.6528 - val_accuracy: 0.7783
# Epoch 76/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3302 - accuracy: 0.8792 - val_loss: 0.2926 - val_accuracy: 0.8847
# Epoch 77/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2169 - accuracy: 0.9169 - val_loss: 0.5446 - val_accuracy: 0.8087
# Epoch 78/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2287 - accuracy: 0.9141 - val_loss: 0.2187 - val_accuracy: 0.9161
# Epoch 79/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2053 - accuracy: 0.9229 - val_loss: 0.4509 - val_accuracy: 0.8400
# Epoch 80/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2688 - accuracy: 0.9008 - val_loss: 0.2450 - val_accuracy: 0.9043
# Epoch 81/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1723 - accuracy: 0.9355 - val_loss: 0.6365 - val_accuracy: 0.7974
# Epoch 82/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2645 - accuracy: 0.9040 - val_loss: 0.1886 - val_accuracy: 0.9245
# Epoch 83/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1543 - accuracy: 0.9438 - val_loss: 0.3243 - val_accuracy: 0.8808
# Epoch 84/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1334 - accuracy: 0.9506 - val_loss: 0.9216 - val_accuracy: 0.7473
# Epoch 85/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3740 - accuracy: 0.8777 - val_loss: 0.2759 - val_accuracy: 0.8944
# Epoch 86/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1645 - accuracy: 0.9396 - val_loss: 0.1377 - val_accuracy: 0.9460
# Epoch 87/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0919 - accuracy: 0.9690 - val_loss: 0.1956 - val_accuracy: 0.9240
# Epoch 88/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1074 - accuracy: 0.9613 - val_loss: 0.5377 - val_accuracy: 0.8428
# Epoch 89/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1808 - accuracy: 0.9343 - val_loss: 0.2827 - val_accuracy: 0.8982
# Epoch 90/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1208 - accuracy: 0.9565 - val_loss: 1.4118 - val_accuracy: 0.6041
# Epoch 91/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4317 - accuracy: 0.8699 - val_loss: 0.1472 - val_accuracy: 0.9473
# Epoch 92/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0937 - accuracy: 0.9692 - val_loss: 0.1204 - val_accuracy: 0.9539
# Epoch 93/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1441 - accuracy: 0.9454 - val_loss: 0.1754 - val_accuracy: 0.9314
# Epoch 94/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0702 - accuracy: 0.9775 - val_loss: 0.2944 - val_accuracy: 0.9033
# Epoch 95/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1522 - accuracy: 0.9507 - val_loss: 0.1866 - val_accuracy: 0.9272
# Epoch 96/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0857 - accuracy: 0.9686 - val_loss: 0.1239 - val_accuracy: 0.9543
# Epoch 97/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9780 - val_loss: 0.1789 - val_accuracy: 0.9342
# Epoch 98/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.9721 - val_loss: 0.2024 - val_accuracy: 0.9257
# Epoch 99/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.1032 - accuracy: 0.9628 - val_loss: 0.5794 - val_accuracy: 0.8492
# Epoch 100/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.2568 - accuracy: 0.9142 - val_loss: 0.1100 - val_accuracy: 0.9616
# Epoch 101/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0502 - accuracy: 0.9860 - val_loss: 0.0722 - val_accuracy: 0.9739
# Epoch 102/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9659 - val_loss: 0.2122 - val_accuracy: 0.9211
# Epoch 103/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0589 - accuracy: 0.9812 - val_loss: 0.0838 - val_accuracy: 0.9682
# Epoch 104/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0569 - accuracy: 0.9794 - val_loss: 0.1982 - val_accuracy: 0.9239
# Epoch 105/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1593 - accuracy: 0.9398 - val_loss: 0.1428 - val_accuracy: 0.9480
# Epoch 106/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0436 - accuracy: 0.9874 - val_loss: 0.0480 - val_accuracy: 0.9831
# Epoch 107/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9927 - val_loss: 0.0569 - val_accuracy: 0.9817
# Epoch 108/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 0.9903 - val_loss: 0.1932 - val_accuracy: 0.9304
# Epoch 109/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1003 - accuracy: 0.9663 - val_loss: 0.0710 - val_accuracy: 0.9760
# Epoch 110/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 0.9900 - val_loss: 0.3602 - val_accuracy: 0.8745
# Epoch 111/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1347 - accuracy: 0.9534 - val_loss: 0.1256 - val_accuracy: 0.9506
# Epoch 112/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0579 - accuracy: 0.9803 - val_loss: 0.0588 - val_accuracy: 0.9793
# Epoch 113/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 0.9948 - val_loss: 0.0495 - val_accuracy: 0.9823
# Epoch 114/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0719 - accuracy: 0.9746 - val_loss: 0.4092 - val_accuracy: 0.8831
# Epoch 115/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.1764 - accuracy: 0.9430 - val_loss: 0.1071 - val_accuracy: 0.9610
# Epoch 116/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 0.9909 - val_loss: 0.0575 - val_accuracy: 0.9796
# Epoch 117/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9810 - val_loss: 0.4384 - val_accuracy: 0.8731
# Epoch 118/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2423 - accuracy: 0.9281 - val_loss: 0.1073 - val_accuracy: 0.9614
# Epoch 119/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 0.9865 - val_loss: 0.0798 - val_accuracy: 0.9711
# Epoch 120/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 0.9904 - val_loss: 0.0369 - val_accuracy: 0.9875
# Epoch 121/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 0.9985 - val_loss: 0.0279 - val_accuracy: 0.9911
# Epoch 122/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 0.9907 - val_loss: 0.2375 - val_accuracy: 0.9240
# Epoch 123/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 0.9602 - val_loss: 0.0990 - val_accuracy: 0.9623
# Epoch 124/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0633 - accuracy: 0.9783 - val_loss: 0.3656 - val_accuracy: 0.8985
# Epoch 125/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1672 - accuracy: 0.9457 - val_loss: 0.0699 - val_accuracy: 0.9761
# Epoch 126/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9958 - val_loss: 0.0269 - val_accuracy: 0.9931
# Epoch 127/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9988 - val_loss: 0.0280 - val_accuracy: 0.9908
# Epoch 128/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9974 - val_loss: 0.4976 - val_accuracy: 0.8823
# Epoch 129/150
# 81/81 [==============================] - 0s 4ms/step - loss: 0.1977 - accuracy: 0.9418 - val_loss: 0.0443 - val_accuracy: 0.9877
# Epoch 130/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 0.9959 - val_loss: 0.0468 - val_accuracy: 0.9846
# Epoch 131/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 0.9949 - val_loss: 0.0588 - val_accuracy: 0.9788
# Epoch 132/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 0.0278 - val_accuracy: 0.9914
# Epoch 133/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 0.0534 - val_accuracy: 0.9806
# Epoch 134/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1708 - accuracy: 0.9501 - val_loss: 0.7067 - val_accuracy: 0.8067
# Epoch 135/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3302 - accuracy: 0.8878 - val_loss: 0.0720 - val_accuracy: 0.9803
# Epoch 136/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 0.9920 - val_loss: 0.1553 - val_accuracy: 0.9450
# Epoch 137/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 0.9886 - val_loss: 0.0333 - val_accuracy: 0.9897
# Epoch 138/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.9990 - val_loss: 0.0182 - val_accuracy: 0.9955
# Epoch 139/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 0.9989 - val_loss: 0.0187 - val_accuracy: 0.9950
# Epoch 140/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 0.9992 - val_loss: 0.0163 - val_accuracy: 0.9953
# Epoch 141/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 1.1013 - val_accuracy: 0.8192
# Epoch 142/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6805 - accuracy: 0.7752 - val_loss: 0.2909 - val_accuracy: 0.8922
# Epoch 143/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1443 - accuracy: 0.9498 - val_loss: 0.1399 - val_accuracy: 0.9466
# Epoch 144/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0757 - accuracy: 0.9742 - val_loss: 0.1643 - val_accuracy: 0.9379
# Epoch 145/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.9714 - val_loss: 0.7401 - val_accuracy: 0.8448
# Epoch 146/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1580 - accuracy: 0.9479 - val_loss: 0.0998 - val_accuracy: 0.9622
# Epoch 147/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0849 - accuracy: 0.9705 - val_loss: 0.0859 - val_accuracy: 0.9687
# Epoch 148/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.9946 - val_loss: 0.0267 - val_accuracy: 0.9925
# Epoch 149/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9969 - val_loss: 0.0182 - val_accuracy: 0.9955
# Epoch 150/150
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 0.9990 - val_loss: 0.0152 - val_accuracy: 0.9962

# %%
testing_result = model_v1.evaluate(x_test, y_test)
training_evaluation = model_v1.evaluate(x_train, y_train)
print(f'Training Accuracy = {training_evaluation[1]*100:.2f}%\nTesting Accuracy = {testing_result[1]*100:.2f}%')
# Out:
# 313/313 [==============================] - 0s 553us/step - loss: 0.0152 - accuracy: 0.9962
# 1251/1251 [==============================] - 1s 558us/step - loss: 0.0050 - accuracy: 0.9995
# Training Accuracy = 99.95%
# Testing Accuracy = 99.62%

# %% [markdown]
# ## Building DFFNN V2
# Here, we will use sklearn's multilayer perceptron.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

model_v2 = MLPClassifier(
            hidden_layer_sizes=(128,128),
            activation='tanh',
            solver='adam',
            batch_size=500,
            learning_rate='constant',
            max_iter=150,
            verbose=True
           )

model_v2.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 1.18062621
# Iteration 2, loss = 0.98338842
# Iteration 3, loss = 0.96989284
# Iteration 4, loss = 0.96372402
# Iteration 5, loss = 0.95835276
# Iteration 6, loss = 0.95769834
# Iteration 7, loss = 0.95742972
# Iteration 8, loss = 0.95496665
# Iteration 9, loss = 0.95464886
# Iteration 10, loss = 0.95226437
# Iteration 11, loss = 0.95129767
# Iteration 12, loss = 0.95146385
# Iteration 13, loss = 0.95066333
# Iteration 14, loss = 0.94896713
# Iteration 15, loss = 0.94792651
# Iteration 16, loss = 0.94667833
# Iteration 17, loss = 0.94578998
# Iteration 18, loss = 0.94618540
# Iteration 19, loss = 0.94357678
# Iteration 20, loss = 0.94247971
# Iteration 21, loss = 0.94140274
# Iteration 22, loss = 0.94058101
# Iteration 23, loss = 0.93818483
# Iteration 24, loss = 0.93762343
# Iteration 25, loss = 0.93556430
# Iteration 26, loss = 0.93232824
# Iteration 27, loss = 0.93228984
# Iteration 28, loss = 0.92878958
# Iteration 29, loss = 0.92592463
# Iteration 30, loss = 0.92567307
# Iteration 31, loss = 0.91856443
# Iteration 32, loss = 0.91644529
# Iteration 33, loss = 0.91176340
# Iteration 34, loss = 0.90574907
# Iteration 35, loss = 0.90096071
# Iteration 36, loss = 0.89399325
# Iteration 37, loss = 0.88823411
# Iteration 38, loss = 0.88008630
# Iteration 39, loss = 0.87204423
# Iteration 40, loss = 0.86307056
# Iteration 41, loss = 0.85311176
# Iteration 42, loss = 0.84155391
# Iteration 43, loss = 0.82713422
# Iteration 44, loss = 0.81275711
# Iteration 45, loss = 0.79878708
# Iteration 46, loss = 0.78255414
# Iteration 47, loss = 0.76507170
# Iteration 48, loss = 0.74734700
# Iteration 49, loss = 0.72859684
# Iteration 50, loss = 0.70954109
# Iteration 51, loss = 0.69136429
# Iteration 52, loss = 0.67245883
# Iteration 53, loss = 0.65165246
# Iteration 54, loss = 0.62998015
# Iteration 55, loss = 0.60941789
# Iteration 56, loss = 0.58882584
# Iteration 57, loss = 0.56785365
# Iteration 58, loss = 0.54786791
# Iteration 59, loss = 0.52602589
# Iteration 60, loss = 0.50648567
# Iteration 61, loss = 0.48652340
# Iteration 62, loss = 0.46741822
# Iteration 63, loss = 0.44971772
# Iteration 64, loss = 0.43307143
# Iteration 65, loss = 0.41668639
# Iteration 66, loss = 0.40188797
# Iteration 67, loss = 0.38731010
# Iteration 68, loss = 0.37421091
# Iteration 69, loss = 0.36146592
# Iteration 70, loss = 0.35037561
# Iteration 71, loss = 0.33898065
# Iteration 72, loss = 0.32840316
# Iteration 73, loss = 0.31806321
# Iteration 74, loss = 0.30931522
# Iteration 75, loss = 0.30058087
# Iteration 76, loss = 0.29234379
# Iteration 77, loss = 0.28478538
# Iteration 78, loss = 0.27897834
# Iteration 79, loss = 0.26894969
# Iteration 80, loss = 0.26329520
# Iteration 81, loss = 0.25594246
# Iteration 82, loss = 0.25022484
# Iteration 83, loss = 0.24374089
# Iteration 84, loss = 0.23726515
# Iteration 85, loss = 0.23229362
# Iteration 86, loss = 0.22660242
# Iteration 87, loss = 0.22150146
# Iteration 88, loss = 0.21603124
# Iteration 89, loss = 0.21300010
# Iteration 90, loss = 0.21066655
# Iteration 91, loss = 0.20359826
# Iteration 92, loss = 0.19819860
# Iteration 93, loss = 0.19599810
# Iteration 94, loss = 0.19002339
# Iteration 95, loss = 0.18636814
# Iteration 96, loss = 0.18317888
# Iteration 97, loss = 0.17915968
# Iteration 98, loss = 0.17534214
# Iteration 99, loss = 0.17236810
# Iteration 100, loss = 0.16837113
# Iteration 101, loss = 0.16579640
# Iteration 102, loss = 0.16292744
# Iteration 103, loss = 0.15884126
# Iteration 104, loss = 0.15577139
# Iteration 105, loss = 0.15382633
# Iteration 106, loss = 0.15129872
# Iteration 107, loss = 0.14925588
# Iteration 108, loss = 0.14458945
# Iteration 109, loss = 0.14288796
# Iteration 110, loss = 0.13955819
# Iteration 111, loss = 0.13701451
# Iteration 112, loss = 0.13684001
# Iteration 113, loss = 0.13291224
# Iteration 114, loss = 0.13102444
# Iteration 115, loss = 0.12878986
# Iteration 116, loss = 0.12570098
# Iteration 117, loss = 0.12379620
# Iteration 118, loss = 0.12289027
# Iteration 119, loss = 0.11961146
# Iteration 120, loss = 0.11761581
# Iteration 121, loss = 0.11830738
# Iteration 122, loss = 0.11468546
# Iteration 123, loss = 0.11192759
# Iteration 124, loss = 0.11085219
# Iteration 125, loss = 0.10951834
# Iteration 126, loss = 0.10681435
# Iteration 127, loss = 0.10635132
# Iteration 128, loss = 0.10346844
# Iteration 129, loss = 0.10280756
# Iteration 130, loss = 0.10086341
# Iteration 131, loss = 0.09882297
# Iteration 132, loss = 0.09757831
# Iteration 133, loss = 0.09601779
# Iteration 134, loss = 0.09463476
# Iteration 135, loss = 0.09301285
# Iteration 136, loss = 0.09195599
# Iteration 137, loss = 0.09052771
# Iteration 138, loss = 0.09194528
# Iteration 139, loss = 0.08826036
# Iteration 140, loss = 0.08671701
# Iteration 141, loss = 0.08511969
# Iteration 142, loss = 0.08378146
# Iteration 143, loss = 0.08260845
# Iteration 144, loss = 0.08256817
# Iteration 145, loss = 0.08053435
# Iteration 146, loss = 0.07914370
# Iteration 147, loss = 0.07807599
# Iteration 148, loss = 0.07796883
# Iteration 149, loss = 0.07601701
# Iteration 150, loss = 0.07576195
# MLPClassifier(activation='tanh', batch_size=500, hidden_layer_sizes=(128, 128),
#               max_iter=150, verbose=True)

# %%
y_pred = model_v2.predict(x_test)
print(f'Testing Accuracy = {accuracy_score(y_test, y_pred)*100}%')
# Out:
# Testing Accuracy = 97.7109156337465%

# %% [markdown]
# ## Conclusion
#
# If we compare our both versions, we can see that v1 is clearly the best model. However, if we increase some parameters in sklearn's model, we can achieve similar results in v2. Furthermore, we can increase our test data and then see the accuracy. However, we already divided the test set into the same size as of train set and with that both of the models performed very well. Hence, we will save both of them for comparative study.

# %% [markdown]
# ## Saving the model

# %%
model_v1.save('dl_v1.h5')

import pickle
pickle.dump(model_v2, open('dl_v2.pkl', 'wb'))

# %% [markdown]
# ## Using the models

# %%
from keras.models import load_model
import pickle

model_1 = load_model('dl_v1.h5')
model_2 = pickle.load(open('dl_v2.pkl', 'rb'))

# %%
import numpy as np

pred_1 = model_1.predict(np.array([2,11,2,13,2,10,2,12,2,1]).reshape(1,-1)).argmax()
pred_2 = model_2.predict(np.array([2,11,2,13,2,10,2,12,2,1]).reshape(1,-1))

print(pred_1, pred_2)
# Out:
# 2 [9]

# %%
pred_1 = model_1.predict(np.array([4,1,4,13,4,12,4,11,4,10]).reshape(1,-1)).argmax()
pred_2 = model_2.predict(np.array([1,2,1,4,1,5,1,3,1,6]).reshape(1,-1))

print(pred_1, pred_2)
# Out:
# 2 [4]

# %% [markdown]
# This concludes our deep learning session.
